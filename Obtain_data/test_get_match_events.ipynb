# %%
import requests
import json
import pandas as pd
import os
from datetime import datetime
import re
import random 
import time 
from IPython.display import display, clear_output, HTML
import glob

# %%
# Test for the final match of men's China Smash 2025 
event_id = "3098"
match_code = "TTEMSINGLES-----------FNL-000100----------"

# %%
def get_match_card_details(event_id, match_code):
    """
    Fetches the detailed summary card for a single match.

    Args:
        event_id (int or str): The ID of the event.
        match_code (str): The unique document code for the match.

    Returns:
        dict: The JSON response data as a Python dictionary, or None if an error occurs.
    """
    # The URL is an f-string to dynamically insert the event and match codes
    url = f"https://liveeventsapi.worldtabletennis.com/api/cms/GetMatchCardDetails/{event_id}/{match_code}"
    
    # The parameters from the end of the cURL URL
    params = {
        'no_cache': 'true',
        'require_full_msg': 'true',
        'require_play_by_play_full': 'true'
    }
    
    headers = {
        'Accept': 'application/json',
        'Accept-Language': 'en-GB,en;q=0.9,es;q=0.8',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json',
        'DNT': '1',
        'Origin': 'https://www.worldtabletennis.com',
        'Pragma': 'no-cache',
        'Referer': 'https://www.worldtabletennis.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Linux; Android 11.0; Surface Duo) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Mobile Safari/537.36',
        'sec-ch-ua': '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
        'sec-ch-ua-mobile': '?1',
        'sec-ch-ua-platform': '"Android"'
    }
    
    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status() # Raise an error for bad status codes
        return response.json()
    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error for match {match_code}: {err}")
    except requests.exceptions.RequestException as err:
        print(f"An error occurred for match {match_code}: {err}")
        
    return None

# %%
sample_event_id = 3098
sample_match_code = "TTEMSINGLES-----------FNL-000100----------"

match_details = get_match_card_details(sample_event_id, sample_match_code)

if match_details:
    print(f"✅ Success! Details for match {sample_match_code}:")
    # Pretty-print the JSON response for easy viewing
    # print(json.dumps(match_details, indent=2))
# Out:
# ✅ Success! Details for match TTEMSINGLES-----------FNL-000100----------:

# %%
feed = match_details["full_msg"]

# %%
feed.keys()
# Out:
# dict_keys(['PlayByPlay', 'Results_all'])

# %%
feed_dict = feed["PlayByPlay"][0]

# %%
feed_df = pd.DataFrame(feed_dict)

# %%
feed_df.columns
# Out:
# Index(['MessageType', 'MessagePayLoad', 'Sequencenumber'], dtype='object')

# %%
feed_series = feed_df.iloc[3]["MessagePayLoad"]

# %%
feed_series.keys()
# Out:
# dict_keys(['ExtendedInfos', 'Actions', 'ActionsProgressionByGame', 'Gen', 'Sport', 'Codes'])

# %%
feed_series["ActionsProgressionByGame"][-1].keys()
# Out:
# dict_keys(['SeqNo', 'ActionType', 'Period', 'TossWonby', 'ServerCompetitor', 'ServerPlayer', 'ServerReceiver', 'ServerNext', 'ReceiverNext', 'SideSelection', 'SideSelectedBy', 'RightSide', 'LeftSide', 'IsWinner', 'ScoreH', 'ScoreA', 'CardType', 'CardIssuedCompetitor', 'CardIssuedPlayer', 'CardIssuedCoach', 'CardIssuedTo', 'TimeoutRequestedBy', 'TimeoutStatus', 'MedicalBreakRequestedBy', 'MedicalBreakStatus', 'ReceiverCompetitor', 'ReceiverPlayer', 'SuddenDeathPoint', 'MatchPoint', 'GamePoint', 'ChampionshipPoint', 'Irm', 'Player_IRM', 'ActionedFor', 'MatchWinner', 'ExtendedInfos'])

# %%
match_details["full_msg"]["Results_all"][0]["MessagePayLoad"]
# Out:
# {'MatchId': 'TTEMSINGLES-----------FNL-000100--',
#  'SequenceNumber': 8,
#  'TableNo': 'T01',
#  'ResultStatus': 'OFFICIAL',
#  'Competition': {'ExtendedInfos': {'UnitDateTime': {'StartDateLocal': '2025-10-05T18:00:00',
#     'StartDateUTC': '2025-10-05T10:00:00',
#     'Duration': '00:24:47'},
#    'SportDescription': {'DisciplineName': 'Table Tennis',
#     'EventName': "Men's Singles",
#     'MatchDescription': "Men's Singles - Final - Match 1",
#     'Gender': 'M',
#     'BestOfXGames': 7,
#     'UnitNum': '1',
#     'PhaseName': 'FNL-',
#     'MaxPointsPerGame': 11,
#     'AdvantagePerGame': 2,
#     'SuddenDeathPoint': 99,
#     'TtrReview': True,
#     'MaxChallengesPerCompetitor': 99,
#     'YellowCard': True,
#     'YellowRed1': True,
#     'YellowRed2': True,
#     'PeriodDescription': [{'Game': 'G1',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G2',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G3',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G4',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G5',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G6',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99},
#      {'Game': 'G7',
#       'MaxPointsPerGame': 11,
#       'AdvantagePerGame': 2,
#       'SuddenDeathPoint': 99}],
#     'IndividualMatchType': 0,
#     'MaxGamesPerIndividualMatch': 0},
#    'VenueDescription': {'Venue': 'TTV',
#     'VenueName': 'Shougang Park',
#     'Location': 'T01',
#     'LocationName': 'Table 1'},
#    'ExtendedInfo': [{'Extension': None,
#      'Type': 'UI',
#      'Code': 'TABLE',
#      'Pos': None,
#      'Value': 'T01'},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'SERVE',
#      'Pos': '1',
#      'Value': 'A'},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'CURRENT',
#      'Pos': None,
#      'Value': '4'},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'CARD',
#      'Pos': 'H',
#      'Value': None},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'CARD',
#      'Pos': 'A',
#      'Value': None},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'FINAL_RESULT',
#      'Pos': None,
#      'Value': '4-0'},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'RALLY_MAX',
#      'Pos': None,
#      'Value': None},
#     {'Extension': None,
#      'Type': 'UI',
#      'Code': 'RALLY_AVG',
#      'Pos': None,
#      'Value': None}]},
#   'Officials': [],
#   'Periods': {'Home': '121558',
#    'Away': '135977',
#    'Period': [{'Code': 'G1',
#      'HomeScore': 1,
#      'AwayScore': 0,
#      'HomePeriodScore': 11,
#      'AwayPeriodScore': 7,
#      'Duration': '00:08:27',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G2',
#      'HomeScore': 2,
#      'AwayScore': 0,
#      'HomePeriodScore': 11,
#      'AwayPeriodScore': 2,
#      'Duration': '00:05:00',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G3',
#      'HomeScore': 3,
#      'AwayScore': 0,
#      'HomePeriodScore': 11,
#      'AwayPeriodScore': 5,
#      'Duration': '00:07:16',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G4',
#      'HomeScore': 4,
#      'AwayScore': 0,
#      'HomePeriodScore': 11,
#      'AwayPeriodScore': 7,
#      'Duration': '00:06:02',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G5',
#      'HomeScore': 4,
#      'AwayScore': 0,
#      'HomePeriodScore': 0,
#      'AwayPeriodScore': 0,
#      'Duration': '00:00:00',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G6',
#      'HomeScore': 4,
#      'AwayScore': 0,
#      'HomePeriodScore': 0,
#      'AwayPeriodScore': 0,
#      'Duration': '00:00:00',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]},
#     {'Code': 'G7',
#      'HomeScore': 4,
#      'AwayScore': 0,
#      'HomePeriodScore': 0,
#      'AwayPeriodScore': 0,
#      'Duration': '00:00:00',
#      'ExtendedPeriods': [{'Type': 'EP', 'Code': 'RALLY_MAX', 'Value': None},
#       {'Type': 'EP', 'Code': 'RALLY_AVG', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINSPINRATE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXSPINDIRECTION', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINHEIGHTOFNETCLEARANCE', 'Value': None},
#       {'Type': 'EP', 'Code': 'AVGPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MAXPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINPLAYERREACTIONTIME', 'Value': None},
#       {'Type': 'EP', 'Code': 'MINBALLSPEED', 'Value': None},
#       {'Type': 'EP', 'Code': 'BALLPLACEMENT', 'Value': None}]}]},
#   'Result': [{'Result': 4,
#     'Irm': 'OK',
#     'Wlt': 'W',
#     'SortOrder': 1,
#     'StartSortOrder': 1,
#     'ResultType': 'POINTS',
#     'ResultItems': {'ResultItem': []},
#     'Competitor': [{'Code': '121558',
#       'Type': 'A',
#       'Wlt': 'W',
#       'RoundforRankingCal': None,
#       'Organization': 'CHN',
#       'Description': None,
#       'EventUnitEntry': [{'Type': 'RAN', 'Code': 'SEED', 'Value': '1'},
#        {'Type': 'RAN', 'Code': 'QUALF', 'Value': 'NO'},
#        {'Type': 'RAN', 'Code': 'CURRANK', 'Value': '1'},
#        {'Type': 'RAN',
#         'Code': 'NUMBEROFMATCHESPLAYEDINSUBEVENT',
#         'Value': '6'},
#        {'Type': 'RAN', 'Code': 'BYE', 'Value': 'False'}],
#       'StatsItems': {'StatsItem': [{'Code': 'PTS_WON',
#          'Pos': 'TOT',
#          'Value': '44'},
#         {'Code': 'LEAD_MAX', 'Pos': 'TOT', 'Value': '9'},
#         {'Code': 'LEAD_MAX_AGNST', 'Pos': 'TOT', 'Value': '1'},
#         {'Code': 'PTS_SERVICE_WON', 'Pos': 'TOT', 'Value': '26'},
#         {'Code': 'PTS_OPP_SERVICE_WON', 'Pos': 'TOT', 'Value': '18'},
#         {'Code': 'PTS_SERVICE_LOST', 'Pos': 'TOT', 'Value': '7'},
#         {'Code': 'PTS_OPP_SERVICE_LOST', 'Pos': 'TOT', 'Value': '14'},
#         {'Code': 'PTS_CONSEC', 'Pos': 'TOT', 'Value': '6'},
#         {'Code': 'DEF_OVC_MAX', 'Pos': 'TOT', 'Value': '1'}]},
#       'Composition': [{'Athlete': [{'Description': {'GivenName': 'Chuqin',
#            'FamilyName': 'WANG',
#            'Gender': 'M',
#            'Organization': 'CHN',
#            'BirthDate': '2000-05-11',
#            'IfId': '121558',
#            'Class': None,
#            'Seed': 1},
#           'EventUnitEntry': [{'Type': 'EUE',
#             'Code': 'GRIP',
#             'Value': 'Shakehand'},
#            {'Type': 'EUE', 'Code': 'HAND', 'Value': 'L'},
#            {'Type': 'EUE', 'Code': 'SEED', 'Value': '1'},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGTYPEA', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGCOLORA', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGTYPEB', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGCOLORB', 'Value': None},
#            {'Type': 'EQU', 'Code': 'BLADETYPE', 'Value': None}],
#           'StatsItems': {'Stats': [{'Type': 'ST',
#              'Code': 'PTS_WON',
#              'Pos': 'G1',
#              'Value': '11'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G1', 'Value': '6'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G1',
#              'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G1',
#              'Value': '5'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G1',
#              'Value': '6'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G1',
#              'Value': '3'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G1',
#              'Value': '4'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G1', 'Value': '3'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G1', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G2', 'Value': '11'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G2', 'Value': '9'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G2',
#              'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G2',
#              'Value': '7'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G2',
#              'Value': '4'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G2',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G2',
#              'Value': '2'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G2', 'Value': '6'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G2', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G3', 'Value': '11'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G3', 'Value': '7'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G3',
#              'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G3',
#              'Value': '6'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G3',
#              'Value': '5'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G3',
#              'Value': '2'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G3',
#              'Value': '3'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G3', 'Value': '4'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G3', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G4', 'Value': '11'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G4', 'Value': '4'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G4',
#              'Value': '1'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G4',
#              'Value': '8'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G4',
#              'Value': '3'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G4',
#              'Value': '2'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G4',
#              'Value': '5'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G4', 'Value': '5'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G4', 'Value': '1'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G7', 'Value': ''}]},
#           'Code': '121558',
#           'Order': 1}]}]}]},
#    {'Result': 0,
#     'Irm': 'OK',
#     'Wlt': 'L',
#     'SortOrder': 2,
#     'StartSortOrder': 2,
#     'ResultType': 'POINTS',
#     'ResultItems': {'ResultItem': []},
#     'Competitor': [{'Code': '135977',
#       'Type': 'A',
#       'Wlt': 'L',
#       'RoundforRankingCal': None,
#       'Organization': 'FRA',
#       'Description': None,
#       'EventUnitEntry': [{'Type': 'RAN', 'Code': 'SEED', 'Value': '7'},
#        {'Type': 'RAN', 'Code': 'QUALF', 'Value': 'NO'},
#        {'Type': 'RAN', 'Code': 'CURRANK', 'Value': '7'},
#        {'Type': 'RAN',
#         'Code': 'NUMBEROFMATCHESPLAYEDINSUBEVENT',
#         'Value': '6'},
#        {'Type': 'RAN', 'Code': 'BYE', 'Value': 'False'}],
#       'StatsItems': {'StatsItem': [{'Code': 'PTS_WON',
#          'Pos': 'TOT',
#          'Value': '21'},
#         {'Code': 'LEAD_MAX', 'Pos': 'TOT', 'Value': '1'},
#         {'Code': 'LEAD_MAX_AGNST', 'Pos': 'TOT', 'Value': '9'},
#         {'Code': 'PTS_SERVICE_WON', 'Pos': 'TOT', 'Value': '14'},
#         {'Code': 'PTS_OPP_SERVICE_WON', 'Pos': 'TOT', 'Value': '7'},
#         {'Code': 'PTS_SERVICE_LOST', 'Pos': 'TOT', 'Value': '18'},
#         {'Code': 'PTS_OPP_SERVICE_LOST', 'Pos': 'TOT', 'Value': '26'},
#         {'Code': 'PTS_CONSEC', 'Pos': 'TOT', 'Value': '3'},
#         {'Code': 'DEF_OVC_MAX', 'Pos': 'TOT', 'Value': '-'}]},
#       'Composition': [{'Athlete': [{'Description': {'GivenName': 'Felix',
#            'FamilyName': 'LEBRUN',
#            'Gender': 'M',
#            'Organization': 'FRA',
#            'BirthDate': '2006-09-12',
#            'IfId': '135977',
#            'Class': None,
#            'Seed': 7},
#           'EventUnitEntry': [{'Type': 'EUE',
#             'Code': 'GRIP',
#             'Value': 'Penhold'},
#            {'Type': 'EUE', 'Code': 'HAND', 'Value': 'R'},
#            {'Type': 'EUE', 'Code': 'SEED', 'Value': '7'},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGTYPEA', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGCOLORA', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGTYPEB', 'Value': None},
#            {'Type': 'EQU', 'Code': 'RACKETCOVERINGCOLORB', 'Value': None},
#            {'Type': 'EQU', 'Code': 'BLADETYPE', 'Value': None}],
#           'StatsItems': {'Stats': [{'Type': 'ST',
#              'Code': 'PTS_WON',
#              'Pos': 'G1',
#              'Value': '7'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G1', 'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G1',
#              'Value': '6'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G1',
#              'Value': '4'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G1',
#              'Value': '3'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G1',
#              'Value': '6'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G1',
#              'Value': '5'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G1', 'Value': '3'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G1', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G2', 'Value': '2'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G2', 'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G2',
#              'Value': '9'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G2',
#              'Value': '2'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G2',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G2',
#              'Value': '4'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G2',
#              'Value': '7'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G2', 'Value': '1'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G2', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G3', 'Value': '5'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G3', 'Value': '0'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G3',
#              'Value': '7'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G3',
#              'Value': '3'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G3',
#              'Value': '2'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G3',
#              'Value': '5'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G3',
#              'Value': '6'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G3', 'Value': '2'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G3', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G4', 'Value': '7'},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G4', 'Value': '1'},
#             {'Type': 'ST',
#              'Code': 'LEAD_MAX_AGNST',
#              'Pos': 'G4',
#              'Value': '4'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G4',
#              'Value': '5'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G4',
#              'Value': '2'},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G4',
#              'Value': '3'},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G4',
#              'Value': '8'},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G4', 'Value': '3'},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G4', 'Value': '0'},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G5',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G5', 'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G6',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G6', 'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_WON', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'LEAD_MAX_AGNST', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_WON',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_WON',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_SERVICE_LOST',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST',
#              'Code': 'PTS_OPP_SERVICE_LOST',
#              'Pos': 'G7',
#              'Value': ''},
#             {'Type': 'ST', 'Code': 'PTS_CONSEC', 'Pos': 'G7', 'Value': ''},
#             {'Type': 'ST', 'Code': 'DEF_OVC_MAX', 'Pos': 'G7', 'Value': ''}]},
#           'Code': '135977',
#           'Order': 1}]}]}]}],
#   'Gen': None,
#   'Sport': None,
#   'Codes': None},
#  'CompetitionCode': 'WTT-2025-3098-TEV-WGS',
#  'DocumentCode': 'TTEMSINGLES-----------FNL-000100--',
#  'DocumentType': 'DT_RESULT',
#  'Version': '1',
#  'FeedFlag': 'P',
#  'LogicalDate': '2025-10-05',
#  'LogicalTime': '185025829',
#  'UtcDate': '2025-10-05',
#  'UtcTime': '105025829',
#  'LocalDate': '2025-10-05',
#  'LocalTime': '185025829',
#  'Source': 'OVR',
#  'EventId': '3098',
#  'ClusterRegion': 'sea'}
