# %%
import requests
import json
import pandas as pd
import os

output_dir="./"

# %%
def get_events_by_year(year):
    """
    Fetches all the WTT events and event info for specified year_rangesand saves as csv.
    Args:
        year (int or str): The year to fetch events for.
        output_dir (str): The directory to save the raw data in.
        
    Returns:
        bool: True if successful, False otherwise.
    """
    url = 'https://wtt-website-api-prod-3-frontdoor-bddnb2haduafdze9.a01.azurefd.net/api/eventcalendar'

    headers = {
        'accept': 'application/json, text/plain, */*',
        'origin': 'https://www.worldtabletennis.com',
        'referer': 'https://www.worldtabletennis.com/',
        'user-agent': 'Mozilla/5.0 (Linux; Android 11.0; Surface Duo) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Mobile Safari/537.36'
    }

    data = {
        "custom_filter": f"[{{\"name\":\"StartDateTime\",\"value\":{year},\"custom_handling\":\"multimatch_year_or_filter\",\"condition\":\"or_start\"}},{{\"name\":\"FromStartDate\",\"value\":{year},\"custom_handling\":\"multimatch_year_or_filter\",\"condition\":\"or_end\"}}]"
    }

    try:
        print(f"Fetching events for the {year}")
        response = requests.post(url, headers=headers, json=data)
        response.raise_for_status()

        response_data = response.json()
        events_list = response_data[0].get('rows')

        if not (events_list and isinstance(events_list, list)):
            print(f"No event data found for {year} - {end_year}.")
            return False

        # --- Create DataFrame with ALL columns from the API response ---
        df = pd.DataFrame(events_list)
        print(f"Found {len(df)} events.)

        # Create the output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
        filename = f'{output_dir}/raw_events_{year}.csv'
        
        df.to_csv(filename, index=False)
        print(f"✅ Raw data successfully saved to {filename}")
        return True

    except requests.exceptions.HTTPError as err:
        print(f"❌ HTTP Error: {err}")
    except json.JSONDecodeError:
        print(f"❌ Error: The response was not valid JSON.")
    except Exception as err:
        print(f"❌ An unexpected error occurred: {err}")
    
    return False


if __name__ == "__main__":

    # Year from which to obtain events
    years = range(2020,2026)
   
    
    print("--- Starting WTT Events Scraper --- \n   ")
    for year in years:
        print (f" ----------- Starting searching year {year}-----------" )  
        get_events_by_year(year=year, output_dir="Data/Raw/Events")
        print (f" ----------- Finished searching year {year} -----------\n   ")
    print("--- Scraping finished. ---")
# Out:
# --- Starting WTT Events Scraper ---
#
#  ----------- Starting searching year 2020-----------
# Fetching events for the 2020
# Found 66 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2020.csv
#  ----------- Finished searching year 2020 -----------
#
#  ----------- Starting searching year 2021-----------
# Fetching events for the 2021
# Found 100 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2021.csv
#  ----------- Finished searching year 2021 -----------
#
#  ----------- Starting searching year 2022-----------
# Fetching events for the 2022
# Found 94 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2022.csv
#  ----------- Finished searching year 2022 -----------
#
#  ----------- Starting searching year 2023-----------
# Fetching events for the 2023
# Found 107 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2023.csv
#  ----------- Finished searching year 2023 -----------
#
#  ----------- Starting searching year 2024-----------
# Fetching events for the 2024
# Found 136 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2024.csv
#  ----------- Finished searching year 2024 -----------
#
#  ----------- Starting searching year 2025-----------
# Fetching events for the 2025
# Found 173 events. Saving to raw CSV...
# ✅ Raw data successfully saved to Data/Raw/Events/raw_events_2025.csv
#  ----------- Finished searching year 2025 -----------
#
# --- Scraping finished. ---
