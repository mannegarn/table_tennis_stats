# %%
import sys
import os
import pandas as pd




project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    

from utils.getLatestFiles import get_latest_master_players, get_latest_master_matches, get_latest_master_events, get_latest_sponsors_data
from utils.ratings import calculate_ratings_history, get_final_player_stats
# Out:
# 2025-11-25 12:26:14.681 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.682 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.683 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.683 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.684 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.685 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:14.686 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
matches_df, update_date = get_latest_master_matches()
players_df = get_latest_master_players()
events_df = get_latest_master_events()
# Out:
# 2025-11-25 12:26:15.035 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-25 12:26:15.037 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 12:26:15.104
# ...
#   command:
#
#     streamlit run /home/mdannegarn/table_tennis_stats/.venv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-25 12:26:15.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 12:26:15.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 12:26:15.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 12:26:15.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
update_date
# Out:
# Timestamp('2025-11-25 00:00:00')

# %%
matches_df
# Out:
#        eventId                                documentCode     subEventName  \
# 0         2410          TTEMSINGLES-----------RND1000700--      Men Singles
# 1         2410          TTEMSINGLES-----------RND1002600--      Men Singles
# 2         2410          TTEMSINGLES-----------RND1004600--      Men Singles
# 3         2410          TTEMSINGLES-----------RND1001900--      Men Singles
# 4         2410          TTEMSINGLES-----------RND1001000--      Men Singles
# ...        ...                                         ...              ...
# 23877     3176  TTEMSINGLES-----------R64-003000----------    Men's Singles
# 23878     3176  TTEWSINGLES-----------R64-002700----------  Women's Singles
# 23879     3176  TTEMSINGLES-----------R64-003100----------    Men's Singles
# 23880     3176  TTEWSINGLES-----------R64-002300----------  Women's Singles
# 23881     3176  TTEMSINGLES-----------R64-002300----------    Men's Singles
#
#                                   subEventDescription  \
# ...

# %%
ratings_df = calculate_ratings_history(players_df= players_df, matches_df=matches_df, info_string="Overall")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ratings_df = calculate_ratings_history(master_players_df, master_matches_df, info_string="Overall")
#
# NameError: name 'calculate_ratings_history' is not defined

# %%
final_stats_df = get_final_player_stats(ratings_df, info_string="Overall")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 final_stats_df = get_final_player_stats(ratings_df, info_string="Overall")
#
# NameError: name 'get_final_player_stats' is not defined

# %%
women_ids = master_players_df[master_players_df["Gender"] == "F"]
men_ids = master_players_df[master_players_df["Gender"] == "M"]

# %%
men_final_stats_df = final_stats_df[final_stats_df["playerId"].isin(men_ids["playerId"])]
women_final_stats_df = final_stats_df[final_stats_df["playerId"].isin(women_ids["playerId"])]

# %%
men_final_stats_df.sort_values(by=["ratingMax (Overall)"], ascending=False)
# Out:
#       playerId           playerName playerCountry  ratingFinal (Overall)  \
# 2       121558          WANG Chuqin           CHN                2468.92
# 5       121404         FAN Zhendong           CHN                2364.54
# 8       137237          LIN Shidong           CHN                2348.91
# 7       105649              MA Long           CHN                2353.74
# 13      115641       CALDERANO Hugo           BRA                2300.45
# ...        ...                  ...           ...                    ...
# 1815    211710  CARDENAS Cristopher           VEN                1383.36
# 1816    123090         ALLEYNE Joel           GUY                1383.36
# 1817    136090        KOJAL Kennedy           KEN                1383.36
# 1818    136028     SENKBEIL Vincent           GER                1383.36
# 1799    209975      ADEYEMI Olamide           NGR                1383.36
#
#       totalMatches (Overall)  totalWins (Overall)  winRate (Overall)  \
# ...

# %%
men_final_stats_df.sort_values(by=["ratingAvg (Overall)"], ascending=False)
# Out:
#       playerId            playerName playerCountry  ratingFinal (Overall)  \
# 2       121558           WANG Chuqin           CHN                2468.92
# 5       121404          FAN Zhendong           CHN                2364.54
# 7       105649               MA Long           CHN                2353.74
# 15      119588         LIANG Jingkun           CHN                2277.41
# 8       137237           LIN Shidong           CHN                2348.91
# ...        ...                   ...           ...                    ...
# 2627    135387         DILLON Adrian           AUT                1137.11
# 2657    204499        AHMADIAN Mahdi           REF                1076.08
# 2633    121420       ALMUTAIRI Turki           KSA                1127.59
# 2650    134774         NEUMANN Layan           MEX                1101.27
# 2527    144667  ABDULWAHHAB Abdullah           QAT                1220.27
#
#       totalMatches (Overall)  totalWins (Overall)  winRate (Overall)  \
# ...

# %%
women_final_stats_df.sort_values(by=["ratingMax (Overall)"], ascending=False)
# Out:
#       playerId            playerName playerCountry  ratingFinal (Overall)  \
# 0       131163           SUN Yingsha           CHN                2674.82
# 1       121411            WANG Manyu           CHN                2505.58
# 3       112019             CHEN Meng           CHN                2450.56
# 4       121403         CHEN Xingtong           CHN                2392.44
# 6       124110             WANG Yidi           CHN                2363.49
# ...        ...                   ...           ...                    ...
# 1761    136503  LIMA Chancia Cynthia           BEN                1383.36
# 1766    105678        MADAREE Arisha           RSA                1383.36
# 1767    201203        YAMANAKA Erika           PER                1383.36
# 1772    200365  BOGHUMA KAHLIH BOBGA           CMR                1383.36
# 1811    131473      NTUMNYUY Harriet           CMR                1383.36
#
#       totalMatches (Overall)  totalWins (Overall)  winRate (Overall)  \
# ...

# %%
ratings_df
# Out:
#        eventId                       EventName  \
# 0         2410         WTT Contender Doha 2021
# 1         2410         WTT Contender Doha 2021
# 2         2410         WTT Contender Doha 2021
# 3         2410         WTT Contender Doha 2021
# 4         2410         WTT Contender Doha 2021
# ...        ...                             ...
# 23573     3176  WTT Star Contender Muscat 2025
# 23574     3176  WTT Star Contender Muscat 2025
# 23575     3176  WTT Star Contender Muscat 2025
# 23576     3176  WTT Star Contender Muscat 2025
# 23577     3176  WTT Star Contender Muscat 2025
#
#                                      documentCode  \
# 0              TTEMSINGLES-----------RND1000700--
# 1              TTEMSINGLES-----------RND1002600--
# 2              TTEMSINGLES-----------RND1004600--
# 3              TTEMSINGLES-----------RND1001900--
# 4              TTEMSINGLES-----------RND1001000--
# ...                                           ...
# ...
