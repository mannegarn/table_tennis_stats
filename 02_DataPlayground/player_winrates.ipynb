# %%
import sys
import os
import pandas as pd
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    

from utils.getLatestFiles import get_latest_master_players, get_latest_master_matches, get_latest_master_events

from utils.winrates import get_player_winrates

# %%
master_players_df = get_latest_master_players()
master_matches_df = get_latest_master_matches()
master_events_df = get_latest_master_events()
# Out:
# ✅ 2684 players found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Players/20251113_master_players.csv
# ✅ 23690 matches found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Matches/20251112_master_matches.csv
# ✅ 187 events found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Events/20251113_master_events.csv

# %%
overall_winrates_df = get_player_winrates(master_players_df, master_matches_df, min_matches=5, info_string="Overall")

# %%
overall_winrates_df
# Out:
#       playerId          PlayerName       CountryName  WinRate (Overall)  \
# 0       131163         SUN Yingsha             China              91.26
# 1       121558         WANG Chuqin             China              86.50
# 2       114947    Valeriia KOTSIUR               AIN              85.71
# 3       121404        FAN Zhendong             China              84.95
# 4       210318            XU Jiayi             China              83.33
# ...        ...                 ...               ...                ...
# 1246    135639       Akos KISHEGYI           Hungary               0.00
# 1247    136566       Lukas KRAEMER           Austria               0.00
# 1248    134567  Andre Pierre KASES           Austria               0.00
# 1249    202502         Tammi AGARI  Papua New Guinea               0.00
# 1250    134339     Klara HRABICOVA           Czechia               0.00
#
#       TotalMatches (Overall)  TotalWins (Overall)  TotalLosses (Overall)
# 0                        183                  167                     16
# 1                        163                  141                     22
# 2                         14                   12                      2
# 3                         93                   79                     14
# 4                          6                    5                      1
# ...                      ...                  ...                    ...
# 1246                       5                    0                      5
# 1247                       6                    0                      6
# 1248                      11                    0                     11
# 1249                       7                    0                      7
# 1250                      10                    0                     10
#
# [1251 rows x 7 columns]

# %%
grippy_tables = ["DHS", "Double Fish", "Yinhe"]
fast_tables = ["Tibhar", "Stiga", "Joola", "Donic"]
grippy_event_ids = master_events_df[master_events_df["TableSponsor"].isin(grippy_tables)]["eventId"].unique()
fast_event_ids = master_events_df[master_events_df["TableSponsor"].isin(fast_tables)]["eventId"].unique()

grippy_matches_df = master_matches_df[master_matches_df["eventId"].isin(grippy_event_ids)]
fast_matches_df = master_matches_df[master_matches_df["eventId"].isin(fast_event_ids)]

# %%
grippy_winrates_df = get_player_winrates(master_players_df, grippy_matches_df, 
                                         min_matches=10, info_string ="grippy tables")
fast_winrates_df = get_player_winrates(master_players_df, fast_matches_df,
                                        min_matches=10, info_string="fast tables")

# %%
grippy_winrates_df
# Out:
#      playerId       PlayerName CountryName  WinRate (grippy tables)  \
# 0      131163      SUN Yingsha       China                    92.26
# 1      135179      Haruna OJIO       Japan                    90.00
# 2      121558      WANG Chuqin       China                    87.69
# 3      121404     FAN Zhendong       China                    85.71
# 4      119529         FAN Siqi       China                    84.00
# ..        ...              ...         ...                      ...
# 352    120726  Mariam ALHODABY       Egypt                    10.53
# 353    134356   Arantxa COSSIO      Mexico                     9.09
# 354    100439      Ahmed SALEH       Egypt                     9.09
# 355    123935         Vicky WU        Fiji                     7.69
# 356    109777     Paulina VEGA       Chile                     6.25
#
#      TotalMatches (grippy tables)  TotalWins (grippy tables)  \
# 0                             155                        143
# 1                              10                          9
# 2                             130                        114
# 3                              77                         66
# 4                              25                         21
# ..                            ...                        ...
# 352                            19                          2
# 353                            11                          1
# 354                            11                          1
# 355                            13                          1
# 356                            16                          1
#
#      TotalLosses (grippy tables)
# 0                             12
# 1                              1
# 2                             16
# 3                             11
# 4                              4
# ..                           ...
# 352                           17
# 353                           10
# 354                           10
# 355                           12
# 356                           15
#
# [357 rows x 7 columns]

# %%
fast_winrates_df
# Out:
#      playerId        PlayerName CountryName  WinRate (fast tables)  \
# 0      121404      FAN Zhendong       China                  90.00
# 1      131163       SUN Yingsha       China                  88.89
# 2      119588     LIANG Jingkun       China                  86.21
# 3      133000  Honoka HASHIMOTO       Japan                  84.38
# 4      121558       WANG Chuqin       China                  84.00
# ..        ...               ...         ...                    ...
# 532    123666  Katarina STRAZAR    Slovenia                   7.14
# 533    123198   Elisavet TERPOU      Greece                   0.00
# 534    134158       Aljaz GODEC    Slovenia                   0.00
# 535    134176       Tjasa NOVAK    Slovenia                   0.00
# 536    134339   Klara HRABICOVA     Czechia                   0.00
#
#      TotalMatches (fast tables)  TotalWins (fast tables)  \
# 0                            10                        9
# 1                            18                       16
# 2                            29                       25
# 3                            32                       27
# 4                            25                       21
# ..                          ...                      ...
# 532                          14                        1
# 533                          12                        0
# 534                          11                        0
# 535                          10                        0
# 536                          10                        0
#
#      TotalLosses (fast tables)
# 0                            1
# 1                            2
# 2                            4
# 3                            5
# 4                            4
# ..                         ...
# 532                         13
# 533                         12
# 534                         11
# 535                         10
# 536                         10
#
# [537 rows x 7 columns]

# %%
fast_vs_grippy_df = grippy_winrates_df.merge(fast_winrates_df, how="inner", on=["playerId", "PlayerName", "CountryName"])

# %%
fast_vs_grippy_df
# Out:
#      playerId       PlayerName  CountryName  WinRate (grippy tables)  \
# 0      131163      SUN Yingsha        China                    92.26
# 1      135179      Haruna OJIO        Japan                    90.00
# 2      121558      WANG Chuqin        China                    87.69
# 3      121404     FAN Zhendong        China                    85.71
# 4      121411       WANG Manyu        China                    83.09
# ..        ...              ...          ...                      ...
# 315    111512  Daniel GONZALEZ  Puerto Rico                    14.29
# 316    113908     Yousra HELMY        Egypt                    14.29
# 317    120726  Mariam ALHODABY        Egypt                    10.53
# 318    134356   Arantxa COSSIO       Mexico                     9.09
# 319    109777     Paulina VEGA        Chile                     6.25
#
#      TotalMatches (grippy tables)  TotalWins (grippy tables)  \
# 0                             155                        143
# 1                              10                          9
# 2                             130                        114
# 3                              77                         66
# 4                             136                        113
# ..                            ...                        ...
# 315                            21                          3
# 316                            21                          3
# 317                            19                          2
# 318                            11                          1
# 319                            16                          1
#
#      TotalLosses (grippy tables)  WinRate (fast tables)  \
# 0                             12                  88.89
# 1                              1                  68.18
# 2                             16                  84.00
# 3                             11                  90.00
# 4                             23                  80.00
# ..                           ...                    ...
# 315                           18                  27.78
# 316                           18                  33.33
# 317                           17                  33.33
# 318                           10                  42.11
# 319                           15                  33.33
#
#      TotalMatches (fast tables)  TotalWins (fast tables)  \
# 0                            18                       16
# 1                            22                       15
# 2                            25                       21
# 3                            10                        9
# 4                            15                       12
# ..                          ...                      ...
# 315                          18                        5
# 316                          21                        7
# 317                          12                        4
# 318                          19                        8
# 319                          27                        9
#
#      TotalLosses (fast tables)
# 0                            2
# 1                            7
# 2                            4
# 3                            1
# 4                            3
# ..                         ...
# 315                         13
# 316                         14
# 317                          8
# 318                         11
# 319                         18
#
# [320 rows x 11 columns]

# %%
fast_vs_grippy_df["Fast vs Grippy Winrate Diff"] = fast_vs_grippy_df["WinRate (fast tables)"] - fast_vs_grippy_df["WinRate (grippy tables)"]
fast_vs_grippy_df["Fast vs Grippy Winrate Diff"] = fast_vs_grippy_df["Fast vs Grippy Winrate Diff"].round(2)

# %%
fast_vs_grippy_df = fast_vs_grippy_df.sort_values(by=["Fast vs Grippy Winrate Diff"], ascending=False)

# %%
fast_vs_grippy_df = fast_vs_grippy_df[["playerId", "PlayerName", "CountryName", "WinRate (fast tables)", "WinRate (grippy tables)", "Fast vs Grippy Winrate Diff", "TotalMatches (fast tables)", "TotalMatches (grippy tables)"]]

# %%
fast_vs_grippy_df.columns
# Out:
# Index(['playerId', 'PlayerName', 'CountryName', 'WinRate (fast tables)',
#        'WinRate (grippy tables)', 'Fast vs Grippy Winrate Diff',
#        'TotalMatches (fast tables)', 'TotalMatches (grippy tables)'],
#       dtype='object')

# %%
fast_vs_grippy_df[fast_vs_grippy_df["CountryName"] =="France"]
# Out:
#      playerId           PlayerName CountryName  WinRate (fast tables)  \
# 284    134718       Thibault PORET      France                  57.14
# 195    122002        Lilian BARDET      France                  60.78
# 181    131100      Prithika PAVADE      France                  61.90
# 263    116874         Audrey ZARIF      France                  50.98
# 98     132992        Alexis LEBRUN      France                  65.91
# 126    112062          Simon GAUZY      France                  61.36
# 150    123300        Jules ROLLAND      France                  58.93
# 31     135977         Felix LEBRUN      France                  76.47
# 187    122095      Bastien REMBERT      France                  52.00
# 60     117003     Alexandre CASSIN      France                  66.67
# 106    135501       Charlotte LUTZ      France                  58.70
# 244    116921    Pauline CHASSELIN      France                  42.86
# 92     133652         Esteban DORR      France                  58.33
# 147    137894         Jia Nan YUAN      France                  50.00
# 87     117002         Joe SEYFRIED      France                  55.88
# 216    105136    Emmanuel LEBESSON      France                  41.67
# 114    120857  Florian BOURRASSAUD      France                  50.00
# 102    134590       Hugo DESCHAMPS      France                  50.00
# 53     116612           Can AKKUZU      France                  55.26
# 131    123550         Camille LUTZ      France                  41.38
#
#      WinRate (grippy tables)  Fast vs Grippy Winrate Diff  \
# 284                    31.25                        25.89
# 195                    45.45                        15.33
# 181                    47.17                        14.73
# 263                    36.67                        14.31
# 98                     55.17                        10.74
# 126                    52.24                         9.12
# 150                    50.00                         8.93
# 31                     70.51                         5.96
# 187                    46.15                         5.85
# 60                     61.29                         5.38
# 106                    54.17                         4.53
# 244                    40.00                         2.86
# 92                     56.25                         2.08
# 147                    50.00                         0.00
# 87                     57.14                        -1.26
# 216                    43.75                        -2.08
# 114                    53.33                        -3.33
# 102                    54.55                        -4.55
# 53                     62.86                        -7.60
# 131                    51.61                       -10.23
#
#      TotalMatches (fast tables)  TotalMatches (grippy tables)
# 284                          28                            16
# 195                          51                            22
# 181                          42                            53
# 263                          51                            30
# 98                           44                            58
# 126                          44                            67
# 150                          56                            18
# 31                           51                            78
# 187                          25                            13
# 60                           24                            31
# 106                          46                            24
# 244                          14                            10
# 92                           24                            16
# 147                          22                            66
# 87                           34                            14
# 216                          12                            16
# 114                          20                            15
# 102                          12                            11
# 53                           38                            35
# 131                          29                            31

# %%
def get_country_winrate_diffs(player_stats_df: pd.DataFrame, min_players: int = 1) -> pd.DataFrame:
    """
    Aggregates player-level win rate differences up to the country level.

    Args:
        player_stats_df (pd.DataFrame): The DataFrame from your example, containing
                                        ['CountryName', 'Fast vs Grippy Winrate Diff', 'playerId'].
        min_players (int, optional): The minimum number of players a country must have
                                     to be included in the final report. Defaults to 1.

    Returns:
        pd.DataFrame: A DataFrame indexed by CountryName, showing the average difference
                      and the number of players.
    """
    
    # 1. Group by 'CountryName' and aggregate multiple stats at once
    country_stats_df = player_stats_df.groupby('CountryName').agg(
        # Calculate the mean of the difference column
        Average_WinRate_Diff=('Fast vs Grippy Winrate Diff', 'mean'),
        
        # Count the number of unique players from that country
        PlayerCount=('playerId', 'nunique')
    )
    
    # 2. Apply the minimum player filter
    if min_players > 1:
        country_stats_df = country_stats_df[country_stats_df['PlayerCount'] >= min_players]
        
    # 3. Sort by the average difference (descending)
    country_stats_df = country_stats_df.sort_values(by='Average_WinRate_Diff', ascending=False)
    
    # 4. Round the average for cleaner output
    country_stats_df['Average_WinRate_Diff'] = country_stats_df['Average_WinRate_Diff'].round(2)
    
    return country_stats_df

# %%
country_diff_report = get_country_winrate_diffs(fast_vs_grippy_df, min_players=5)

print("--- Average Win Rate Difference by Country (min 5 players) ---")
display(country_diff_report)
# Out:
# --- Average Win Rate Difference by Country (min 5 players) ---
#                   Average_WinRate_Diff  PlayerCount
# CountryName
# Egypt                            20.66            7
# Sweden                           10.97            7
# Brazil                            9.70            6
# Romania                           8.46           14
# Singapore                         7.92            8
# Portugal                          7.92            6
# Germany                           5.98           17
# Croatia                           5.37            8
# France                            4.83           20
# Japan                             3.67           25
# Korea Republic                    3.55           21
# Austria                           3.51            5
# England                           2.79            5
# Hong Kong, China                  2.31           10
# India                             1.95           17
# Italy                             1.65            6
# Poland                            1.48            7
# Chinese Taipei                    0.85           18
# China                            -0.42           39
# Slovak Republic                  -1.06            5

# %%
import pandas as pd
import numpy as np

def get_country_winrate_diffs_weighted(player_stats_df: pd.DataFrame, min_players: int = 1) -> pd.DataFrame:
    """
    Aggregates player-level win rate differences up to the country level,
    weighted by the total number of matches each player played.

    Args:
        player_stats_df (pd.DataFrame): The DataFrame from your example, containing
                                        ['CountryName', 'Fast vs Grippy Winrate Diff', 
                                         'TotalMatches (fast tables)', 'TotalMatches (grippy tables)',
                                         'playerId'].
        min_players (int, optional): The minimum number of players a country must have
                                     to be included in the final report. Defaults to 1.

    Returns:
        pd.DataFrame: A DataFrame indexed by CountryName, showing the weighted
                      average difference, total matches, and player count.
    """
    
    # --- Weighted Average Calculation ---
    
    # 1. Create a copy to avoid modifying your original DataFrame
    df_copy = player_stats_df.copy()
    
    # 2. Calculate the "Weight" for each player (their total matches)
    df_copy['PlayerTotalMatches'] = df_copy['TotalMatches (fast tables)'] + df_copy['TotalMatches (grippy tables)']
    
    # 3. Calculate the "Weighted Value" for each player
    # (Player's Diff * Player's Total Matches)
    df_copy['WeightedDiff'] = df_copy['Fast vs Grippy Winrate Diff'] * df_copy['PlayerTotalMatches']
    
    # 4. Group by 'CountryName' and sum up the components
    country_stats_df = df_copy.groupby('CountryName').agg(
        # Get the sum of all weighted diffs
        TotalWeightedDiff=('WeightedDiff', 'sum'),
        
        # Get the sum of all matches (this is our total weight)
        TotalCountryMatches=('PlayerTotalMatches', 'sum'),
        
        # Count unique players for the filter
        PlayerCount=('playerId', 'nunique')
    )
    
    # 5. Calculate the final Weighted Average
    # (Sum of all WeightedDiffs) / (Sum of all TotalMatches)
    # Use .fillna(0) in case TotalCountryMatches is 0 to avoid DivisionByZeroError
    country_stats_df['WeightedAvg_WinRate_Diff'] = (
        country_stats_df['TotalWeightedDiff'] / country_stats_df['TotalCountryMatches']
    ).fillna(0)
    
    # --- End of Calculation ---
    
    
    # 6. Apply the minimum player filter
    if min_players > 1:
        country_stats_df = country_stats_df[country_stats_df['PlayerCount'] >= min_players]
        
    # 7. Sort by the weighted average difference (descending)
    country_stats_df = country_stats_df.sort_values(by='WeightedAvg_WinRate_Diff', ascending=False)
    
    # 8. Clean up for the final report
    country_stats_df['WeightedAvg_WinRate_Diff'] = country_stats_df['WeightedAvg_WinRate_Diff'].round(2)
    
    # Return the clean, final table, dropping the intermediate calculation column
    return country_stats_df.drop(columns=['TotalWeightedDiff'])

# %%
country_weighted_report = get_country_winrate_diffs_weighted(fast_vs_grippy_df, min_players=5)

# %%
finals_df = master_matches_df[master_matches_df["Round"]=="Final"]
finals_winrates_df = get_player_winrates(master_players_df, finals_df, min_matches=1, info_string="Finals")    
finals_winrates_df = finals_winrates_df.sort_values(by=["WinRate (Finals)", "TotalMatches (Finals)"], ascending=False)
finals_winrates_df
# Out:
#      playerId        PlayerName     CountryName  WinRate (Finals)  \
# 25     117821          Mima ITO           Japan             100.0
# 2      134800      Nicholas LUM       Australia             100.0
# 23     119542       Sakura MORI           Japan             100.0
# 0      134442  Hiroto SHINOZUKA           Japan             100.0
# 8      123971      CHO Daeseong  Korea Republic             100.0
# ..        ...               ...             ...               ...
# 232    137238    HUANG Youzheng           China               0.0
# 233    121408      LIU Dingshuo           China               0.0
# 235    116874      Audrey ZARIF          France               0.0
# 236    134246   Amirreza ABBASI            Iran               0.0
# 238    136180        Elvira RAD           Spain               0.0
#
#      TotalMatches (Finals)  TotalWins (Finals)  TotalLosses (Finals)
# 25                       5                   5                     0
# 2                        3                   3                     0
# 23                       3                   3                     0
# 0                        2                   2                     0
# 8                        2                   2                     0
# ..                     ...                 ...                   ...
# 232                      1                   0                     1
# 233                      1                   0                     1
# 235                      1                   0                     1
# 236                      1                   0                     1
# 238                      1                   0                     1
#
# [241 rows x 7 columns]

# %%
master_matches_df.columns
# Out:
# Index(['eventId', 'documentCode', 'subEventName', 'subEventDescription',
#        'venueName', 'tableName', 'dnf', 'ttrReview', 'serverNext',
#        'duration (unreliable)', 'EventName', 'EventStartDate', 'matchDate',
#        'overallScore', 'gameScore', 'Winner', 'bestOf', 'winnerName',
#        'winnerId', 'winnerCountry', 'loserName', 'loserId', 'loserCountry',
#        'winnerSets', 'loserSets', 'totalSets', 'isStraightSets', 'isDecider',
#        'winnerTotalPoints', 'loserTotalPoints', 'totalPoints',
#        'winnerPointsRatio', 'loserPointsRatio', 'winnerMaxScore',
#        'loserMaxScore', 'maxScore', 'numberDeuceGames', 'winnerDeuceWon',
#        'loserDeuceWon', 'winnerPointsDifference', 'pointsPerSet',
#        'winnerDroppedFirstSet', 'winner0Wins', 'winner1Wins', 'winner4Wins',
#        'loser0Wins', 'loser1Wins', 'loser4Wins', 'winnerAvgWinningMargin',
#        'loserAvgWinningMargin', 'comebackBy2', 'comebackBy3',
#        'winnerAvgPointsPerSet', 'loserAvgPointsPerSet', 'Round'],
#       dtype='object')

# %%
bo_5_filter = master_matches_df["bestOf"] == 5
comeback_from_2_filter = master_matches_df["comebackBy2"] == True

bo5_comeback_mask = bo_5_filter & comeback_from_2_filter
bo5_comeback_df = master_matches_df[bo5_comeback_mask]

bo7_filter = master_matches_df["bestOf"] == 7
comeback_from_3_filter = master_matches_df["comebackBy3"] == True

bo7_comeback_mask = bo7_filter & comeback_from_3_filter
bo7_comeback_df = master_matches_df[bo7_comeback_mask]

# %%
bo5_comeback_df
# Out:
#        eventId                                documentCode     subEventName  \
# 5         2410          TTEMSINGLES-----------RND1001800--      Men Singles
# 45        2410          TTEMSINGLES-----------RND2000400--      Men Singles
# 99        2410          TTEWSINGLES-----------RND2002200--    Women Singles
# 121       2410          TTEMSINGLES-----------RND3000400--      Men Singles
# 131       2410          TTEMSINGLES-----------RND3001200--      Men Singles
# ...        ...                                         ...              ...
# 23602     3066  TTEWSINGLES-----------R64-002300----------  Women's Singles
# 23605     3066  TTEWSINGLES-----------R64-001900----------  Women's Singles
# 23649     3066  TTEMSINGLES-----------R32-000200----------    Men's Singles
# 23656     3066  TTEMSINGLES-----------R32-001300----------    Men's Singles
# 23682     3066  TTEMSINGLES-----------QFNL000200----------    Men's Singles
#
#                                     subEventDescription  \
# 5        Men's Singles - Preliminary Round 1 - Match 18
# 45        Men's Singles - Preliminary Round 2 - Match 4
# 99     Women's Singles - Preliminary Round 2 - Match 22
# 121       Men's Singles - Preliminary Round 3 - Match 4
# 131      Men's Singles - Preliminary Round 3 - Match 12
# ...                                                 ...
# 23602          Women's Singles - Round of 64 - Match 23
# 23605          Women's Singles - Round of 64 - Match 19
# 23649             Men's Singles - Round of 32 - Match 2
# 23656            Men's Singles - Round of 32 - Match 13
# 23682            Men's Singles - Quarterfinal - Match 2
#
#                                      venueName tableName    dnf ttrReview  \
# 5                          Lusail Sports Arena   Table 8  False       NaN
# 45                         Lusail Sports Arena   Table 5  False       NaN
# 99                         Lusail Sports Arena   Table 3  False       NaN
# 121                        Lusail Sports Arena   Table 7  False       NaN
# 131                        Lusail Sports Arena   Table 8  False       NaN
# ...                                        ...       ...    ...       ...
# 23602  Pavilhao Municipal de Vila Nova de Gaia   Table 3  False     False
# 23605  Pavilhao Municipal de Vila Nova de Gaia   Table 6  False     False
# 23649  Pavilhao Municipal de Vila Nova de Gaia   Table 6  False     False
# 23656  Pavilhao Municipal de Vila Nova de Gaia   Table 2  False     False
# 23682  Pavilhao Municipal de Vila Nova de Gaia   Table 1  False     False
#
#        serverNext duration (unreliable)  ... loser0Wins loser1Wins loser4Wins  \
# 5             NaN              00:30:44  ...        0.0        0.0        0.0
# 45            NaN              00:49:08  ...        0.0        0.0        0.0
# 99            NaN              00:40:01  ...        0.0        0.0        0.0
# 121           NaN              00:37:51  ...        0.0        0.0        0.0
# 131           NaN              00:45:28  ...        0.0        0.0        0.0
# ...           ...                   ...  ...        ...        ...        ...
# 23602    119109.0              00:35:09  ...        0.0        0.0        0.0
# 23605    112453.0              00:39:11  ...        0.0        0.0        0.0
# 23649    114410.0              00:47:21  ...        0.0        0.0        0.0
# 23656    120287.0              00:38:12  ...        0.0        0.0        0.0
# 23682    102841.0              00:50:21  ...        0.0        0.0        1.0
#
#       winnerAvgWinningMargin loserAvgWinningMargin comebackBy2  comebackBy3  \
# 5                       4.00                   5.0        True        False
# 45                      2.67                   3.5        True        False
# 99                      3.00                   4.5        True        False
# 121                     4.67                   3.0        True        False
# 131                     3.00                   5.0        True        False
# ...                      ...                   ...         ...          ...
# 23602                   5.33                   3.5        True        False
# 23605                   4.00                   3.5        True        False
# 23649                   3.00                   3.5        True        False
# 23656                   3.67                   4.0        True        False
# 23682                   4.00                   6.0        True        False
#
#       winnerAvgPointsPerSet  loserAvgPointsPerSet         Round
# 5                       9.0                   8.6         Other
# 45                     10.8                  10.6         Other
# 99                      9.2                   9.2         Other
# 121                     9.8                   8.2         Other
# 131                     9.4                   9.6         Other
# ...                     ...                   ...           ...
# 23602                   9.6                   7.8         Other
# 23605                   9.6                   8.6         Other
# 23649                  10.4                  10.0         Other
# 23656                   9.4                   8.8         Other
# 23682                   9.2                   9.2  Quarterfinal
#
# [698 rows x 55 columns]

# %%
bo7_comeback_df
# Out:
#        eventId                                documentCode     subEventName  \
# 430       2345  TTEWSINGLES-----------R128000800----------  Women's Singles
# 500       2345  TTEWSINGLES-----------R32-000300----------  Women's Singles
# 969       2484  TTEWSINGLES-----------GP04000200----------    Women Singles
# 980       2484  TTEMSINGLES-----------GP06000300----------      Men Singles
# 1185      2489  TTEWSINGLES-----------SFNL000100----------    Women Singles
# 1986      2346  TTEMSINGLES-----------8FNL000500----------    Men's Singles
# 2007      2346  TTEMSINGLES-----------QFNL000200----------    Men's Singles
# 2165      2479  TTEMSINGLES-----------FNL-000100----------    Men's Singles
# 2271      2521  TTEMSINGLES-----------R64-002100----------    Men's Singles
# 2288      2521  TTEWSINGLES-----------R32-001300----------  Women's Singles
# 2318      2521  TTEMSINGLES-----------8FNL000300----------    Men's Singles
# 2420      2522  TTEMSINGLES-----------R32-000400----------    Men's Singles
# 4273      2540  TTEWSINGLES-----------R64-000300----------  Women's Singles
# 4706      2592  TTEMSINGLES-----------R64-002000----------    Men's Singles
# 2007    George R. Brown Convention Center   Table 1  False     False
# 2165          Kisakallio Sports Institute   Table 1  False     False
# 2271       Deutsches Tischtennis- Zentrum   Table 2  False     False
# 2288       Deutsches Tischtennis- Zentrum   Table 2  False     False
# 2318       Deutsches Tischtennis- Zentrum   Table 2  False     False
# 2420       Deutsches Tischtennis- Zentrum   Table 2  False     False
# 4273                  Sport Centre Otocec   Table 5  False     False
# 4706                             BOK Hall   Table 4  False     False
# 4818                             BOK Hall   Table 1  False     False
# 5155                   OMEGA Sport Center   Table 4  False     False
# 5330                         Arena Asarel   Table 4  False     False
# 5383           La Coupole- Cit? Olympique   Table 6  False      True
# 5802              Table Tennis Centre ADD   Table 1  False     False
# 6080     Centro de Entrenamiento Olimpico   Table 2  False     False
# 6133     Centro de Entrenamiento Olimpico   Table 3  False     False
# 6298       Deutsches Tischtennis- Zentrum   Table 5  False     False
# 10437        Expocuba Pablell?n Salud #20   Table 3  False      True
# 14309                        Galaxy Arena   Table 1  False     False
# 15791                 South Paris Arena 4   Table 4  False     False
# 15810                 South Paris Arena 4   Table 3  False     False
# 15830                 South Paris Arena 4   Table 2  False     False
# 16939  Auckland Table Tennis Association    Table 1  False      True
# 20270                    Qatar University   Table 8  False      True
# 20337                              Lusail   Table 2  False      True
# 21307                       Orleans Arena   Table 1  False      True
# 23403                 Sud de France ARENA   Table 1  False     False
#
#        serverNext duration (unreliable)  ... loser0Wins loser1Wins loser4Wins  \
# 430           NaN                  0:58  ...        0.0        0.0        0.0
# 500           NaN                  1:02  ...        0.0        0.0        1.0
# 969           NaN              00:38:51  ...        0.0        0.0        1.0
# 980           NaN              00:43:00  ...        0.0        0.0        0.0
# 1185          NaN              00:30:00  ...        0.0        0.0        0.0
# 1986          NaN              00:57:24  ...        0.0        0.0        0.0
# 2007          NaN              01:13:26  ...        0.0        0.0        0.0
# 2165          NaN              01:07:16  ...        0.0        0.0        2.0
# 2271          NaN              00:53:10  ...        0.0        0.0        0.0
# 2288          NaN              00:50:26  ...        0.0        0.0        1.0
# 2318          NaN              01:01:38  ...        0.0        0.0        0.0
# 2420          NaN              00:47:13  ...        0.0        0.0        0.0
# 4273          NaN              00:51:17  ...        0.0        0.0        1.0
# 4706          NaN              01:04:34  ...        0.0        0.0        0.0
# 4818          NaN              00:59:53  ...        0.0        0.0        1.0
# 5155          NaN              00:51:51  ...        0.0        0.0        0.0
# 5330          NaN              00:46:26  ...        1.0        0.0        1.0
# 5383          NaN              00:45:09  ...        0.0        0.0        0.0
# 5802          NaN              01:03:52  ...        0.0        0.0        0.0
# 6080     121440.0              00:54:30  ...        0.0        0.0        0.0
# 6133     105679.0              01:04:15  ...        0.0        0.0        0.0
# 6298     136567.0              01:15:42  ...        0.0        0.0        0.0
# 10437    111498.0              00:43:39  ...        0.0        0.0        1.0
# 14309    105649.0              01:03:44  ...        0.0        0.0        0.0
# 15791         NaN                  0:52  ...        0.0        0.0        0.0
# 15810         NaN                  0:58  ...        0.0        0.0        0.0
# 15830         NaN                  1:09  ...        0.0        0.0        0.0
# 16939    104092.0              00:00:00  ...        0.0        1.0        1.0
# 20270    116021.0              00:59:10  ...        0.0        0.0        1.0
# 20337    123971.0              00:57:13  ...        0.0        0.0        0.0
# 21307    132132.0              01:05:09  ...        0.0        0.0        0.0
# 23403    115543.0              00:57:11  ...        0.0        0.0        0.0
#
#       winnerAvgWinningMargin loserAvgWinningMargin comebackBy2  comebackBy3  \
# 430                     4.75                  2.33        True         True
# 500                     4.50                  4.67        True         True
# 969                     6.25                  5.00        True         True
# 980                     4.25                  3.33        True         True
# 1185                    4.50                  2.67        True         True
# 1986                    5.75                  3.00        True         True
# 2007                    4.00                  2.67        True         True
# 2165                    2.00                  5.67        True         True
# 2271                    5.00                  2.67        True         True
# 2288                    4.75                  5.00        True         True
# 2318                    4.00                  2.67        True         True
# 2420                    6.25                  3.67        True         True
# 4273                    5.25                  3.67        True         True
# 4706                    2.75                  2.33        True         True
# 4818                    3.50                  4.67        True         True
# 5155                    3.00                  4.67        True         True
# 5330                    4.25                  7.00        True         True
# 5383                    2.50                  4.67        True         True
# 5802                    4.00                  3.33        True         True
# 6080                    3.00                  5.00        True         True
# 6133                    4.00                  3.00        True         True
# 6298                    4.50                  5.33        True         True
# 10437                   3.75                  5.00        True         True
# 14309                   4.50                  3.33        True         True
# 15791                   2.25                  3.33        True         True
# 15810                   3.50                  4.00        True         True
# 15830                   4.00                  2.00        True         True
# 16939                   3.50                  6.67        True         True
# 20270                   4.75                  5.33        True         True
# 20337                   5.50                  3.33        True         True
# 21307                   4.25                  4.33        True         True
# 23403                   4.25                  2.33        True         True
#
#       winnerAvgPointsPerSet  loserAvgPointsPerSet         Round
# 430                   10.14                  8.43         Other
# 500                    9.00                  8.43         Other
# 969                    8.86                  7.43         Other
# 980                    9.57                  8.57         Other
# 1185                   9.86                  8.43     Semifinal
# 1986                  10.29                  8.29         Other
# 2007                  10.29                  9.14  Quarterfinal
# 2165                  10.00                 11.29         Final
# 2271                  10.43                  8.71         Other
# 2288                   8.86                  8.29         Other
# 2318                   9.86                  8.71         Other
# 2420                   9.43                  7.43         Other
# 4273                  10.14                  8.71         Other
# 4706                  10.14                  9.57         Other
# 4818                   9.71                  9.71         Final
# 5155                   9.14                  9.43         Other
# 5330                   8.14                  8.71         Other
# 5383                   9.71                 10.29         Other
# 5802                   9.71                  8.86         Final
# 6080                   9.14                  9.57         Other
# 6133                  10.29                  9.29         Other
# 6298                   8.71                  8.43         Other
# 10437                  9.14                  9.14         Other
# 14309                  9.57                  8.43         Final
# 15791                 10.00                 10.14         Other
# 15810                  9.29                  9.00         Other
# 15830                 10.14                  8.71         Other
# 16939                  8.71                  9.57         Final
# 20270                  9.29                  8.86         Other
# 20337                  9.57                  7.86         Other
# 21307                  9.14                  8.57  Quarterfinal
# 23403                 10.29                  8.86  Quarterfinal
#
# [32 rows x 55 columns]

# %%
bo5_comeback_winrates_df = get_player_winrates(master_players_df, bo5_comeback_df, min_matches=1, info_string="Bo5 Comeback")
bo7_comeback_winrates_df = get_player_winrates(master_players_df, bo7_comeback_df, min_matches=1, info_string="Bo7 Comeback")

# %%
bo5_comeback_winrates_df.sort_values(by=[ "TotalWins (Bo5 Comeback)"], ascending=False)
# Out:
#      playerId        PlayerName     CountryName  WinRate (Bo5 Comeback)  \
# 187    132132           CHEN Yi           China                   87.50
# 203    133814       KIM Nayeong  Korea Republic                   75.00
# 258    123977        SHIN Yubin  Korea Republic                   60.00
# 205    114715          Dang QIU         Germany                   75.00
# 190    114848    Martin ALLEGRO         Belgium                   83.33
# ..        ...               ...             ...                     ...
# 602    112075  Hampus SODERLUND          Sweden                    0.00
# 603    102949    Hanna HAPONOVA         Ukraine                    0.00
# 636    122425         Edward LY          Canada                    0.00
# 637    110560          Mo ZHANG          Canada                    0.00
# 638    132124   Undram MUNKHBAT        Mongolia                    0.00
#
#      TotalMatches (Bo5 Comeback)  TotalWins (Bo5 Comeback)  \
# 187                            8                         7
# 203                            8                         6
# 258                           10                         6
# 205                            8                         6
# 190                            6                         5
# ..                           ...                       ...
# 602                            1                         0
# 603                            1                         0
# 636                            1                         0
# 637                            1                         0
# 638                            1                         0
#
#      TotalLosses (Bo5 Comeback)
# 187                           1
# 203                           2
# 258                           4
# 205                           2
# 190                           1
# ..                          ...
# 602                           1
# 603                           1
# 636                           1
# 637                           1
# 638                           1
#
# [639 rows x 7 columns]

# %%
bo5_comeback_winrates_df.sort_values(by=[ "TotalLosses (Bo5 Comeback)"], ascending=False)
# Out:
#      playerId          PlayerName       CountryName  WinRate (Bo5 Comeback)  \
# 409    112062         Simon GAUZY            France                   11.11
# 377    124591       Miyu NAGASAKI             Japan                   33.33
# 408    115546        LAM Siu Hang  Hong Kong, China                   14.29
# 406    135367          OH Junsung    Korea Republic                   16.67
# 407    115454       Natalia BAJOR            Poland                   16.67
# ..        ...                 ...               ...                     ...
# 4      132715           YOO Siwoo    Korea Republic                  100.00
# 3      145304           LIM Yunoh    Korea Republic                  100.00
# 2      136757   Ryoichi YOSHIYAMA             Japan                  100.00
# 1      124042     Daniela FONSECA              Cuba                  100.00
# 0      123894  Jinnipa SAWETTABUT          Thailand                  100.00
#
#      TotalMatches (Bo5 Comeback)  TotalWins (Bo5 Comeback)  \
# 409                            9                         1
# 377                            9                         3
# 408                            7                         1
# 406                            6                         1
# 407                            6                         1
# ..                           ...                       ...
# 4                              1                         1
# 3                              1                         1
# 2                              2                         2
# 1                              1                         1
# 0                              2                         2
#
#      TotalLosses (Bo5 Comeback)
# 409                           8
# 377                           6
# 408                           6
# 406                           5
# 407                           5
# ..                          ...
# 4                             0
# 3                             0
# 2                             0
# 1                             0
# 0                             0
#
# [639 rows x 7 columns]

# %%
bo7_comeback_winrates_df.sort_values(by=[ "TotalLosses (Bo7 Comeback)"], ascending=False)
# Out:
#     playerId           PlayerName       CountryName  WinRate (Bo7 Comeback)  \
# 57    115910          LIN Gaoyuan             China                     0.0
# 51    118507   Christina KALLBERG            Sweden                     0.0
# 53    121582           LIN Yun-Ju    Chinese Taipei                     0.0
# 46    115009         Adriana DIAZ       Puerto Rico                     0.0
# 49    111498      Jeison MARTINEZ        Costa Rica                     0.0
# 48    115543          DOO Hoi Kem  Hong Kong, China                     0.0
# 47    137627           Yangzi LIU         Australia                     0.0
# 44    123300        Jules ROLLAND            France                     0.0
# 39                            1                         0
# 31                            1                         0
# 34                            1                         0
# 32                            1                         0
# 33                            1                         0
# 29                            2                         1
# 30                            1                         0
# 28                            2                         1
# 50                            1                         0
# 56                            1                         0
# 55                            1                         0
# 58                            1                         0
# 52                            1                         0
# 26                            1                         1
# 25                            1                         1
# 24                            1                         1
# 19                            1                         1
# 18                            1                         1
# 17                            1                         1
# 16                            2                         2
# 23                            1                         1
# 22                            1                         1
# 21                            1                         1
# 20                            1                         1
# 11                            1                         1
# 10                            1                         1
# 9                             1                         1
# 8                             1                         1
# 7                             1                         1
# 6                             1                         1
# 5                             1                         1
# 4                             1                         1
# 3                             1                         1
# 2                             1                         1
# 1                             2                         2
# 0                             1                         1
# 15                            1                         1
# 14                            1                         1
# 13                            1                         1
# 12                            1                         1
# 27                            1                         1
#
#     TotalLosses (Bo7 Comeback)
# 57                           2
# 51                           1
# 53                           1
# 46                           1
# 49                           1
# 48                           1
# 47                           1
# 44                           1
# 45                           1
# 43                           1
# 54                           1
# 35                           1
# 42                           1
# 40                           1
# 41                           1
# 38                           1
# 37                           1
# 36                           1
# 39                           1
# 31                           1
# 34                           1
# 32                           1
# 33                           1
# 29                           1
# 30                           1
# 28                           1
# 50                           1
# 56                           1
# 55                           1
# 58                           1
# 52                           1
# 26                           0
# 25                           0
# 24                           0
# 19                           0
# 18                           0
# 17                           0
# 16                           0
# 23                           0
# 22                           0
# 21                           0
# 20                           0
# 11                           0
# 10                           0
# 9                            0
# 8                            0
# 7                            0
# 6                            0
# 5                            0
# 4                            0
# 3                            0
# 2                            0
# 1                            0
# 0                            0
# 15                           0
# 14                           0
# 13                           0
# 12                           0
# 27                           0

# %%
bo7_comeback_winrates_df.sort_values(by=[ "TotalWins (Bo7 Comeback)"], ascending=False)
# Out:
#     playerId           PlayerName       CountryName  WinRate (Bo7 Comeback)  \
# 1     135023       Eduard IONESCU           Romania                   100.0
# 16    106151         Alberto MINO           Ecuador                   100.0
# 0     111683        Gustavo GOMEZ             Chile                   100.0
# 3     119588        LIANG Jingkun             China                   100.0
# 4     118671     Tobias RASMUSSEN           Denmark                   100.0
# 5     116674        Chantal MANTZ           Germany                   100.0
# 6     131581         Nicole ARLIA             Italy                   100.0
# 7     111066        Sabine WINTER           Germany                   100.0
# 8     132886      PYON Song Gyong         Korea DPR                   100.0
# 9     131909      Rebecca HOUNGUE     Cote d'Ivoire                   100.0
# 2     122320       Vladislav URSU           Moldova                   100.0
# 10    131148           XU Yingbin             China                   100.0
# 11    105649              MA Long             China                   100.0
# 13    105679        Marcos MADRID            Mexico                   100.0
# 12    132132              CHEN Yi             China                   100.0
# 14    113701        Britt EERLAND       Netherlands                   100.0
# 15    108742      Kirill SKACHKOV               AIN                   100.0
# 17    122503       Shemar BRITTON            Guyana                   100.0
# 18    113676          Enzo ANGLES            France                   100.0
# 19    122044       Truls MOREGARD            Sweden                   100.0
# 20    102832    Patrick FRANZISKA           Germany                   100.0
# 21    131997        Heorhi KUNATS               AIN                   100.0
# 22    102761          Ruwen FILUS           Germany                   100.0
# 23    132781        Alsu SAPAROVA        Kazakhstan                   100.0
            0
# 3                            0
# 4                            0
# 5                            0
# 6                            0
# 7                            0
# 8                            0
# 9                            0
# 2                            0
# 10                           0
# 11                           0
# 13                           0
# 12                           0
# 14                           0
# 15                           0
# 17                           0
# 18                           0
# 19                           0
# 20                           0
# 21                           0
# 22                           0
# 23                           0
# 24                           0
# 25                           0
# 26                           0
# 27                           0
# 28                           1
# 29                           1
# 30                           1
# 31                           1
# 32                           1
# 33                           1
# 34                           1
# 35                           1
# 36                           1
# 37                           1
# 38                           1
# 39                           1
# 40                           1
# 41                           1
# 42                           1
# 43                           1
# 44                           1
# 45                           1
# 46                           1
# 47                           1
# 48                           1
# 49                           1
# 50                           1
# 51                           1
# 52                           1
# 53                           1
# 54                           1
# 55                           1
# 56                           1
# 57                           2
# 58                           1

# %%
bo7_comeback_df[bo7_comeback_df["loserId"]  == 115910]
# Out:
#        eventId                                documentCode   subEventName  \
# 4818      2593  TTEMSINGLES-----------FNL-000100----------  Men's Singles
# 14309     2937  TTEMSINGLES-----------FNL-000100----------  Men's Singles
#
#                    subEventDescription     venueName tableName    dnf  \
# 4818   Men's Singles - Final - Match 1      BOK Hall   Table 1  False
# 14309  Men's Singles - Final - Match 1  Galaxy Arena   Table 1  False
#
#       ttrReview  serverNext duration (unreliable)  ... loser0Wins loser1Wins  \
# 4818      False         NaN              00:59:53  ...        0.0        0.0
# 14309     False    105649.0              01:03:44  ...        0.0        0.0
#
#       loser4Wins winnerAvgWinningMargin loserAvgWinningMargin comebackBy2  \
# 4818         1.0                    3.5                  4.67        True
# 14309        0.0                    4.5                  3.33        True
#
#        comebackBy3 winnerAvgPointsPerSet  loserAvgPointsPerSet  Round
# 4818          True                  9.71                  9.71  Final
# 14309         True                  9.57                  8.43  Final
#
# [2 rows x 55 columns]

# %%
all_comebacks_filter = bo5_comeback_mask | bo7_comeback_mask
all_comebacks_df = master_matches_df[all_comebacks_filter]
all_comebacks_winrates_df = get_player_winrates(master_players_df, all_comebacks_df, min_matches=1, info_string="All Comebacks")
all_comebacks_winrates_df.sort_values(by=["TotalLosses (All Comebacks)"], ascending=False)
# Out:
#      playerId       PlayerName       CountryName  WinRate (All Comebacks)  \
# 426    112062      Simon GAUZY            France                    11.11
# 425    115546     LAM Siu Hang  Hong Kong, China                    14.29
# 398    124591    Miyu NAGASAKI             Japan                    33.33
# 424    135367       OH Junsung    Korea Republic                    16.67
# 423    115454    Natalia BAJOR            Poland                    16.67
# ..        ...              ...               ...                      ...
# 28     202643  Bhavna HEERALAL      South Africa                   100.00
# 29     123847      Minami ANDO             Japan                   100.00
# 30     202747         ZHU Ziyu             China                   100.00
# 31     132892       LYNE Karen          Malaysia                   100.00
# 32     134790      Asuka SASAO             Japan                   100.00
#
#      TotalMatches (All Comebacks)  TotalWins (All Comebacks)  \
# 426                             9                          1
# 425                             7                          1
# 398                             9                          3
# 424                             6                          1
# 423                             6                          1
# ..                            ...                        ...
# 28                              1                          1
# 29                              1                          1
# 30                              1                          1
# 31                              2                          2
# 32                              2                          2
#
#      TotalLosses (All Comebacks)
# 426                            8
# 425                            6
# 398                            6
# 424                            5
# 423                            5
# ..                           ...
# 28                             0
# 29                             0
# 30                             0
# 31                             0
# 32                             0
#
# [657 rows x 7 columns]

# %%
set([1,2]) == set([2,1])
# Out:
# True
