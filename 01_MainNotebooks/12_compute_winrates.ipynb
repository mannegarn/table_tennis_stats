# %%
import sys 
import os 
from datetime import datetime

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from utils.getLatestFiles import get_latest_master_players, get_latest_master_matches, get_latest_master_events, get_latest_winrates
from utils.winrates import compute_match_winrates, compute_set_winrates, compute_point_winrates, save_winrates

# %%
from math import inf


MASTER_WINRATES_DIR = "../Data/Master/Winrates/"
os.makedirs(MASTER_WINRATES_DIR, exist_ok=True)



master_player_df = get_latest_master_players()
master_match_df = get_latest_master_matches()
master_event_df = get_latest_master_events()

info_string = "Overall"


match_winrates_df = compute_match_winrates(master_match_df, info_string=info_string)
# Out:
# ✅ 2697 players found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Players/20251119_master_players.csv
# ✅ 23882 matches found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Matches/20251120_master_matches.csv
# ✅ 188 events found in latest MASTER: /home/mdannegarn/table_tennis_stats/Data/Master/Events/20251119_master_events.csv
# ✅✅Saved master player winrates to ../Data/Master/Winrates/20251124_winrates_OVERALL.csv

# %%
match_winrates_df = compute_match_winrates(master_match_df, info_string="Overall")
match_winrates_df
# Out:
#       playerId  TotalWins (Overall)  TotalLosses (Overall)  \
# 0       131472                    1                      0
# 1       143600                    1                      0
# 2       131791                    1                      0
# 3       145484                    1                      0
# 4       111964                    1                      0
# ...        ...                  ...                    ...
# 2692    134000                    0                      2
# 2693    105310                    0                      2
# 2694    207488                    0                      2
# 2695    203048                    0                      1
# 2696    117883                    0                      2
#
#       TotalMatches (Overall)  MatchWinRate (Overall)
# 0                          1                   100.0
# 1                          1                   100.0
# 2                          1                   100.0
# ...

# %%
set_winrates_df = compute_set_winrates(master_match_df, info_string="Overall")
set_winrates_df.sort_values('SetWinRate (Overall)', ascending=False)
# Out:
#       playerId  TotalSetsWon (Overall)  TotalSetsLost (Overall)  \
# 1999    145484                       4                        0
# 1540    135288                       4                        0
# 1071    131472                       4                        0
# 1108    131791                       4                        0
# 2513    206221                      14                        3
# ...        ...                     ...                      ...
# 1044    131227                       0                        3
# 1043    131217                       0                        3
# 1041    131196                       0                        3
# 2200    200587                       0                        3
# 2211    200649                       0                       12
#
#       TotalSetsPlayed (Overall)  SetWinRate (Overall)
# 1999                          4                100.00
# 1540                          4                100.00
# ...

# %%
point_winrates_df = compute_point_winrates(master_match_df, info_string="Overall")
point_winrates_df = point_winrates_df.sort_values('PointWinRate (Overall)', ascending=False)
point_winrates_df
# Out:
#       playerId  TotalPointsWon (Overall)  TotalPointsLost (Overall)  \
# 1071    131472                        44                          0
# 1540    135288                        44                          0
# 1108    131791                        44                         16
# 2621    211742                        56                         33
# 2513    206221                       178                        111
# ...        ...                       ...                        ...
# 2313    202095                         0                         99
# 343     113764                         0                        132
# 2069    146065                         0                         33
# 1147    132122                         0                         44
# 2634    211779                         0                         33
#
#       TotalPointsPlayed (Overall)  PointWinRate (Overall)
# 1071                           44                  100.00
# ...

# %%
master_winrates_df = pd.merge (match_winrates_df, set_winrates_df, how="outer", on=["playerId"])
master_winrates_df = pd.merge (master_winrates_df, point_winrates_df, how="outer", on=["playerId"])
save_winrates(master_winrates_df, info_string="Overall")
# Out:
# ✅✅Saved master player winrates to ../Data/Master/Winrates/20251124_winrates_OVERALL.csv

# %%
master_winrates_df
# Out:
#       playerId  TotalWins (Overall)  TotalLosses (Overall)  \
# 0        90051                    2                      1
# 1       100001                    8                     21
# 2       100032                    2                      5
# 3       100079                   11                      5
# 4       100089                    2                      2
# ...        ...                  ...                    ...
# 2692    222286                    0                      5
# 2693    222365                    0                      1
# 2694    222391                    0                      1
# 2695    222625                    2                      1
# 2696    223297                    0                      2
#
#       TotalMatches (Overall)  MatchWinRate (Overall)  TotalSetsWon (Overall)  \
# 0                          3                   66.67                       6
# 1                         29                   27.59                      45
# ...
