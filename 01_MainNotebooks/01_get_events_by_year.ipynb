# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    
from utils.eventsScraper import main_events_scraper

# %%
await main_events_scraper(range(2019, 2026), output_dir= "../Data/Raw/Events/")
# Out:
# --- 🟢 Commencing Event Scraper 🟢---
#
# --- ✅ Scraping Complete ---
# Successfully saved 784 events across 7 files to ../Data/Raw/Events/
